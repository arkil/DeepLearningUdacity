# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

tsld = 1e-5
word_counts =Counter(int_words)
total_count = len(int_words)
frequency ={word : count/total_count for word, count in word_counts.items()}
drop_prob = {word : 1 - np.sqrt(tsld/frequency[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() <1-drop_prob[word]]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R =np.random.randint(1,window_size+1)
    start = idx - R if (idx - R)>0 else 0
    stop = idx+ R
    target_words =set(words[idx:start] + words[idx+1:stop+1])
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32,[None],name="inputs")
    labels = tf.placeholder(tf.int32,[None,None],name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab,n_embedding),-1,1))
    embed = tf.nn.embedding_lookup(embedding,inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6130 0.0835 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5967 0.0785 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5176 0.0779 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5784 0.0779 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5050 0.0780 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5054 0.0780 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5132 0.0778 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5016 0.0796 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5063 0.0816 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4456 0.0829 sec/batch
# Nearest to only: belgians, ibiza, visas, jtc, complete, income, iai, theologies,
# Nearest to there: zeit, nate, melilla, maoism, portion, machine, clout, splice,
# Nearest to will: rowspan, hautes, lifo, hmong, alchemy, carrero, atheistic, hippocrates,
# Nearest to his: pindar, cidre, critical, stipulations, flip, acidification, worshiped, investing,
# Nearest to with: fictitious, defiance, urbanised, band, banquo, palomar, endorheic, effect,
# Nearest to at: homo, marwan, pinched, noailles, cheval, cooked, importance, relates,
# Nearest to war: roz, garnered, priam, rna, alou, mankiewicz, armament, ssh,
# Nearest to used: indispensable, upheaval, bitches, putrajaya, aleksandr, coaching, pillage, sorrows,
# Nearest to mean: niet, kremlin, cagliari, sinatra, spiritism, krona, merseburg, spokesman,
# Nearest to writers: clergy, rosy, popolo, coordinates, louisiane, peabody, cor, locust,
# Nearest to operations: farc, carelessly, linear, profitable, proc, mandola, sut, deeps,
# Nearest to orthodox: mabuse, moods, ladislaus, englishmen, tibet, aphorism, jessie, sacrament,
# Nearest to gold: vox, crew, soares, intensification, beirut, thereupon, craxi, definitional,
# Nearest to cost: ecdysis, newswire, vampire, awkward, cultured, newsweek, blog, heterosexuals,
# Nearest to marriage: rubens, moldavia, yoshi, prince, sommers, schmitz, instinctively, eritrean,
# Nearest to units: biblioth, enactment, universelle, inerrancy, trickery, amorite, dumps, fw,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5257 0.0851 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4635 0.0848 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.4013 0.0855 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.3379 0.0864 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.3080 0.0857 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2962 0.0865 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.2552 0.0875 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.2232 0.0873 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.1436 0.0871 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.1662 0.0868 sec/batch
# Nearest to only: belgians, jtc, complete, sarcoma, conception, al, income, steadman,
# Nearest to there: portion, machine, transform, zeit, chained, last, several, placed,
# Nearest to will: rowspan, hmong, verification, latino, achieve, alchemy, iwerks, tearing,
# Nearest to his: critical, cidre, flip, stipulations, pindar, a, investing, sefirot,
# Nearest to with: band, effect, defiance, fictitious, palomar, synagogue, canceling, thermos,
# Nearest to at: is, actually, importance, marwan, the, that, relates, interactive,
# Nearest to war: armament, communications, garnered, rna, slopes, that, roz, monza,
# Nearest to used: t, indispensable, got, putrajaya, upheaval, wish, relay, wgn,
# Nearest to mean: niet, kremlin, worth, following, cagliari, spiritism, case, krona,
# Nearest to writers: clergy, coordinates, cor, rosy, peabody, louisiane, hook, locust,
# Nearest to operations: farc, carelessly, linear, profitable, mandola, antidepressant, proc, sut,
# Nearest to orthodox: mabuse, moods, jessie, aphorism, stable, boycott, aulis, sacrament,
# Nearest to gold: vox, crew, beirut, soares, definitional, thereupon, intensification, generate,
# Nearest to cost: awkward, ecdysis, extremely, vampire, wu, cultured, langdon, blog,
# Nearest to marriage: rubens, moldavia, prince, yoshi, eritrean, incompatible, instinctively, pronunciation,
# Nearest to units: enactment, biblioth, jewel, universelle, tukey, dumps, amorite, icl,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 5.0818 0.0885 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 5.0634 0.0875 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9941 0.0876 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 5.0066 0.0877 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.9017 0.0872 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.9282 0.0876 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8848 0.0879 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8471 0.0878 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8550 0.0884 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8318 0.0877 sec/batch
# Nearest to only: complete, income, belgians, jtc, sarcoma, al, conception, theologies,
# Nearest to there: portion, machine, transform, zeit, chained, interventions, polar, clout,
# Nearest to will: rowspan, verification, achieve, fell, hmong, hippocrates, blurred, get,
# Nearest to his: critical, flip, cidre, pindar, stipulations, investing, rationally, a,
# Nearest to with: effect, defiance, band, fictitious, palomar, canceling, synagogue, lithuanian,
# Nearest to at: interactive, homo, importance, marwan, relates, property, actually, vague,
# Nearest to war: garnered, communications, armament, rna, slopes, ranged, queen, marshal,
# Nearest to used: indispensable, relay, t, upheaval, acids, got, wgn, putrajaya,
# Nearest to mean: niet, kremlin, worth, following, case, key, cagliari, sell,
# Nearest to writers: clergy, coordinates, cor, rosy, animated, hook, ox, who,
# Nearest to operations: linear, farc, carelessly, profitable, mandola, its, antidepressant, brahe,
# Nearest to orthodox: mabuse, moods, jessie, southern, boycott, aphorism, sacrament, stable,
# Nearest to gold: crew, vox, thereupon, beirut, soares, westminster, bay, intensification,
# Nearest to cost: awkward, extremely, blog, ecdysis, cultured, vampire, wu, newsweek,
# Nearest to marriage: rubens, prince, moldavia, incompatible, yoshi, eritrean, pronunciation, altogether,
# Nearest to units: enactment, jewel, biblioth, tukey, fw, universelle, dumps, spirits,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8180 0.0895 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7902 0.0892 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7855 0.0894 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7233 0.0895 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7985 0.0900 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7487 0.0892 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7340 0.0885 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7677 0.0891 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7284 0.0892 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.7003 0.0891 sec/batch
# Nearest to only: belgians, income, complete, jtc, sarcoma, affecting, visas, secretly,
# Nearest to there: portion, machine, transform, zeit, chained, interventions, polar, clout,
# Nearest to will: rowspan, blurred, verification, atheistic, hippocrates, achieve, upcoming, restructuring,
# Nearest to his: critical, pindar, cidre, stipulations, he, rationally, george, investing,
# Nearest to with: defiance, effect, band, fictitious, lithuanian, boyd, palomar, canceling,
# Nearest to at: marwan, homo, interactive, importance, vague, relates, driscoll, property,
# Nearest to war: garnered, marshal, armament, queen, slopes, rna, independence, volunteered,
# Nearest to used: indispensable, relay, coaching, upheaval, acids, t, hoffman, wgn,
# Nearest to mean: niet, kremlin, sell, case, key, spokesman, cagliari, worth,
# Nearest to writers: clergy, rosy, divorce, louisiane, ox, coordinates, cor, who,
# Nearest to operations: linear, farc, carelessly, profitable, mandola, brahe, antidepressant, proc,
# Nearest to orthodox: mabuse, boycott, jessie, moods, sacrament, tibet, sunni, southern,
# Nearest to gold: crew, vox, beirut, soares, thereupon, intensification, bay, inoculated,
# Nearest to cost: blog, awkward, ecdysis, cultured, extremely, appropriation, vampire, newswire,
# Nearest to marriage: rubens, prince, moldavia, incompatible, yoshi, instinctively, altogether, pronunciation,
# Nearest to units: enactment, biblioth, jewel, fw, tukey, summaries, universelle, angry,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.7076 0.0897 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6968 0.0888 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6678 0.0892 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6863 0.0894 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.7169 0.0889 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6916 0.0884 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6200 0.0671 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5459 0.0886 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5133 0.0883 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4949 0.0878 sec/batch
# Nearest to only: belgians, complete, jtc, income, visas, theologies, affecting, sarcoma,
# Nearest to there: portion, machine, transform, zeit, polar, chained, interventions, maoism,
# Nearest to will: atheistic, rowspan, regimens, blurred, verification, hippocrates, plotters, hmong,
# Nearest to his: critical, he, pindar, cidre, stipulations, rationally, repent, george,
# Nearest to with: defiance, effect, fictitious, band, canceling, palomar, urbanised, synagogue,
# Nearest to at: homo, marwan, interactive, bantam, outlaw, driscoll, whig, importance,
# Nearest to war: garnered, slopes, stanhope, armament, queen, independence, marshal, volunteered,
# Nearest to used: indispensable, relay, coaching, acids, bitches, t, javan, wgn,
# Nearest to mean: niet, kremlin, sell, case, key, use, biz, microscopic,
# Nearest to writers: clergy, louisiane, divorce, locust, rosy, who, ox, peabody,
# Nearest to operations: farc, linear, carelessly, profitable, mandola, brahe, antidepressant, ohm,
# Nearest to orthodox: mabuse, boycott, southern, sacrament, jessie, moods, ladislaus, englishmen,
# Nearest to gold: crew, vox, soares, intensification, beirut, sensed, inoculated, bay,
# Nearest to cost: ecdysis, langdon, appropriation, cultured, blog, newswire, awkward, installation,
# Nearest to marriage: moldavia, prince, rubens, instinctively, incompatible, yoshi, altogether, applicability,
# Nearest to units: enactment, inerrancy, fw, summaries, trickery, harmonic, hindley, finances,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4935 0.0896 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5203 0.0885 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4922 0.0891 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5527 0.0888 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4875 0.0892 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4731 0.0897 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4806 0.0891 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4224 0.0897 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4402 0.0900 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4209 0.0895 sec/batch
# Nearest to only: belgians, visas, complete, theologies, jtc, affecting, income, counselors,
# Nearest to there: portion, machine, transform, polar, interventions, chained, zeit, clout,
# Nearest to will: atheistic, regimens, blurred, rowspan, verification, skiing, hippocrates, hmong,
# Nearest to his: he, critical, pindar, stipulations, repent, cidre, trustworthy, renewing,
# Nearest to with: defiance, effect, fictitious, palomar, excellent, sinai, banquo, amidst,
# Nearest to at: homo, outlaw, marwan, interactive, driscoll, ambrosius, manichaeism, whig,
# Nearest to war: slopes, independence, garnered, stanhope, volunteered, armament, signing, queen,
# Nearest to used: indispensable, relay, acids, wgn, bitches, cas, t, coolers,
# Nearest to mean: niet, kremlin, sell, use, biz, key, microscopic, case,
# Nearest to writers: clergy, louisiane, rosy, pyotr, locust, divorce, who, lana,
# Nearest to operations: farc, linear, carelessly, mandola, deeps, profitable, valves, unexplored,
# Nearest to orthodox: mabuse, sacrament, boycott, southern, ladislaus, jessie, valentinians, englishmen,
# Nearest to gold: crew, vox, soares, robber, beirut, intensification, inoculated, sensed,
# Nearest to cost: langdon, cultured, ecdysis, appropriation, blog, newswire, installation, awkward,
# Nearest to marriage: moldavia, prince, rubens, instinctively, incompatible, yoshi, applicability, altogether,
# Nearest to units: enactment, trickery, hindley, inerrancy, fw, interchange, amorite, universelle,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4474 0.0898 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4353 0.0883 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4523 0.0892 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3923 0.0890 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4185 0.0881 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4419 0.0878 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3898 0.0880 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3917 0.0883 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4219 0.0881 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3667 0.0879 sec/batch
# Nearest to only: belgians, visas, theologies, affecting, counselors, complete, jtc, fitted,
# Nearest to there: portion, transform, zeit, machine, polar, clout, chained, interventions,
# Nearest to will: regimens, atheistic, blurred, verification, rowspan, achieve, get, skiing,
# Nearest to his: he, critical, pindar, repent, stipulations, trustworthy, cidre, renewing,
# Nearest to with: defiance, effect, fictitious, canceling, palomar, amidst, stirred, spans,
# Nearest to at: outlaw, marwan, driscoll, interactive, ambrosius, homo, americo, manichaeism,
# Nearest to war: slopes, independence, armament, stanhope, signing, garnered, volunteered, monza,
# Nearest to used: indispensable, cas, relay, bitches, inserted, wgn, coolers, determinant,
# Nearest to mean: niet, kremlin, microscopic, key, iranic, krautrock, biz, sell,
# Nearest to writers: clergy, louisiane, who, exiguus, lana, pyotr, locust, divorce,
# Nearest to operations: farc, linear, mandola, carelessly, deeps, vend, profitable, atmospheric,
# Nearest to orthodox: sacrament, mabuse, boycott, christian, southern, ladislaus, jessie, englishmen,
# Nearest to gold: crew, vox, robber, cass, craxi, intensification, soares, inoculated,
# Nearest to cost: langdon, installation, newswire, appropriation, ecdysis, cultured, aan, tenderness,
# Nearest to marriage: prince, rubens, moldavia, instinctively, yoshi, incompatible, eritrean, applicability,
# Nearest to units: hindley, enactment, interchange, trickery, smaller, fw, inerrancy, summaries,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3658 0.0894 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3855 0.0883 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3840 0.0885 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3873 0.0887 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.4289 0.0889 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3805 0.0886 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.4016 0.0888 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3893 0.0893 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3437 0.0894 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3323 0.0894 sec/batch
# Nearest to only: visas, affecting, belgians, fitted, counselors, theologies, jtc, income,
# Nearest to there: portion, transform, zeit, polar, clout, chained, maoism, axonal,
# Nearest to will: regimens, atheistic, blurred, achieve, verification, get, plotters, trolleybus,
# Nearest to his: he, critical, pindar, repent, trustworthy, dissonant, replied, renewing,
# Nearest to with: defiance, effect, fictitious, amidst, forage, stirred, band, banquo,
# Nearest to at: outlaw, ambrosius, driscoll, noailles, marwan, warmest, joss, roscoe,
# Nearest to war: independence, signing, slopes, after, armament, volunteered, garnered, marshal,
# Nearest to used: indispensable, cas, coolers, determinant, bitches, relay, wgn, addition,
# Nearest to mean: niet, kremlin, microscopic, use, iranic, zygote, biz, key,
# Nearest to writers: clergy, louisiane, exiguus, lana, pyotr, divorce, who, locust,
# Nearest to operations: farc, linear, carelessly, mandola, vend, deeps, intruders, profitable,
# Nearest to orthodox: sacrament, mabuse, christian, sunni, protestant, boycott, crimes, ladislaus,
# Nearest to gold: crew, inoculated, craxi, robber, cass, intensification, vox, blockading,
# Nearest to cost: langdon, installation, ecdysis, newswire, buggy, tenderness, appropriation, electronically,
# Nearest to marriage: prince, moldavia, rubens, yoshi, instinctively, her, altogether, summoned,
# Nearest to units: hindley, smaller, interchange, fw, inerrancy, enactment, trickery, universelle,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3501 0.0906 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.3418 0.0890 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3774 0.0886 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3907 0.0885 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4002 0.0887 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.3001 0.0884 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3193 0.0881 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3501 0.0880 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2535 0.0890 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2924 0.0888 sec/batch
# Nearest to only: affecting, visas, theologies, belgians, counselors, fitted, jtc, income,
# Nearest to there: portion, transform, maoism, chained, axonal, interventions, tshombe, polar,
# Nearest to will: regimens, atheistic, blurred, achieve, hippocrates, trolleybus, diefenbaker, get,
# Nearest to his: he, critical, replied, pindar, repent, dissonant, wife, trustworthy,
# Nearest to with: defiance, amidst, effect, fictitious, spans, conduit, forage, endorheic,
# Nearest to at: outlaw, driscoll, joss, maximum, carolina, selznick, ambrosius, seminary,
# Nearest to war: independence, forces, armament, signing, slopes, after, northward, marshal,
# Nearest to used: indispensable, determinant, bitches, coolers, cas, inserted, addition, wgn,
# Nearest to mean: niet, iranic, microscopic, krautrock, kremlin, vocabulary, use, biz,
# Nearest to writers: clergy, louisiane, lana, pyotr, exiguus, locust, divorce, whitbread,
# Nearest to operations: farc, linear, carelessly, mandola, intruders, deeps, vend, avalanche,
# Nearest to orthodox: sacrament, sunni, mabuse, christian, protestant, crimes, catholics, eastern,
# Nearest to gold: crew, inoculated, craxi, robber, turkmenistan, tracker, blockading, cass,
# Nearest to cost: installation, langdon, ecdysis, buggy, newswire, tenderness, barriers, grinder,
# Nearest to marriage: prince, rubens, moldavia, summoned, instinctively, incompatible, her, yoshi,
# Nearest to units: hindley, smaller, interchange, trickery, specious, inerrancy, fw, envisage,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3380 0.0895 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3175 0.0882 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3255 0.0445 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2590 0.0885 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2242 0.0880 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2071 0.0876 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.1955 0.0877 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2019 0.0885 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2041 0.0886 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1658 0.0886 sec/batch
# Nearest to only: affecting, visas, fitted, belgians, jtc, theologies, counselors, complete,
# Nearest to there: portion, maoism, transform, chained, axonal, descending, tshombe, several,
# Nearest to will: regimens, atheistic, get, hippocrates, achieve, diefenbaker, blurred, induction,
# Nearest to his: he, critical, repent, replied, pindar, dissonant, octavian, wife,
# Nearest to with: effect, defiance, amidst, banquo, forage, fictitious, endorheic, criticising,
# Nearest to at: outlaw, maximum, driscoll, roscoe, selznick, the, ambrosius, pinched,
# Nearest to war: forces, armament, independence, slopes, liberation, commanded, signing, combat,
# Nearest to used: bitches, cas, indispensable, determinant, coolers, bitmap, addition, relay,
# Nearest to mean: niet, krautrock, iranic, biz, vocabulary, merseburg, spiritism, atheos,
# Nearest to writers: clergy, louisiane, exiguus, lana, pyotr, novels, epistle, tasker,
# Nearest to operations: farc, carelessly, linear, deeps, mandola, intruders, vend, profitable,
# Nearest to orthodox: sacrament, christian, sunni, mabuse, protestant, catholics, liturgy, valentinians,
# Nearest to gold: silver, craxi, inoculated, blockading, robber, crew, soares, zinc,
# Nearest to cost: installation, langdon, buggy, ecdysis, newswire, painless, tenderness, barriers,
# Nearest to marriage: prince, moldavia, rubens, instinctively, summoned, her, yoshi, incompatible,
# Nearest to units: smaller, hindley, specious, interchange, inerrancy, universelle, summaries, trickery,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2145 0.0895 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1991 0.0885 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2024 0.0889 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1311 0.0889 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1678 0.0895 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1540 0.0899 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1510 0.0893 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1550 0.0891 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1750 0.0889 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1565 0.0889 sec/batch
# Nearest to only: affecting, visas, fitted, flatt, counselors, belgians, jtc, complete,
# Nearest to there: portion, transform, several, chained, axonal, is, clout, tshombe,
# Nearest to will: regimens, atheistic, get, diefenbaker, achieve, do, induction, hippocrates,
# Nearest to his: he, pindar, trustworthy, stevie, dissonant, octavian, replied, repent,
# Nearest to with: effect, defiance, fictitious, forage, amidst, criticising, banquo, going,
# Nearest to at: ambrosius, seminary, outlaw, elliptic, maximum, roscoe, the, driscoll,
# Nearest to war: forces, armament, combat, independence, slopes, liberation, commanded, hansa,
# Nearest to used: determinant, cas, indispensable, bitches, vaccinated, coolers, bitmap, inserted,
# Nearest to mean: niet, iranic, krautrock, vocabulary, stubbornly, merseburg, biz, kremlin,
# Nearest to writers: louisiane, clergy, exiguus, novels, lana, pyotr, epistle, tasker,
# Nearest to operations: farc, carelessly, deeps, mandola, intruders, linear, profitable, zhuhai,
# Nearest to orthodox: sacrament, sunni, mabuse, christian, catholics, liturgy, creeds, protestant,
# Nearest to gold: silver, craxi, zinc, inoculated, robber, blockading, tracker, crew,
# Nearest to cost: installation, langdon, ecdysis, buggy, newswire, painless, electronically, appropriation,
# Nearest to marriage: prince, moldavia, rubens, summoned, instinctively, her, incompatible, yoshi,
# Nearest to units: smaller, interchange, hindley, aeg, specious, universelle, trickery, envisage,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1332 0.0900 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2111 0.0883 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1690 0.0887 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1243 0.0884 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1837 0.0888 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1872 0.0885 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1503 0.0886 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1220 0.0881 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1075 0.0885 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1483 0.0881 sec/batch
# Nearest to only: visas, affecting, counselors, flatt, complete, fitted, cotonou, belgians,
# Nearest to there: portion, several, chained, descending, transform, tshombe, clout, axonal,
# Nearest to will: regimens, get, atheistic, achieve, diefenbaker, lughnasadh, optimizing, to,
# Nearest to his: he, pindar, octavian, trustworthy, dissonant, stevie, wife, auntie,
# Nearest to with: forage, effect, defiance, fictitious, amidst, overlapped, timepiece, endorheic,
# Nearest to at: outlaw, seminary, ambrosius, roscoe, elliptic, maximum, blanks, warmest,
# Nearest to war: forces, armament, combat, independence, commanded, slopes, hansa, postwar,
# Nearest to used: bitches, cas, determinant, indispensable, vaccinated, coolers, addition, relay,
# Nearest to mean: niet, iranic, merseburg, kremlin, stubbornly, krautrock, vocabulary, uncanonical,
# Nearest to writers: louisiane, clergy, novels, exiguus, lana, tasker, epistle, pyotr,
# Nearest to operations: farc, linear, mandola, codepages, profitable, deeps, carelessly, intruders,
# Nearest to orthodox: sacrament, sunni, mabuse, eastern, christian, catholics, liturgy, creeds,
# Nearest to gold: silver, zinc, craxi, blockading, robber, amphibians, inoculated, turkmenistan,
# Nearest to cost: installation, langdon, buggy, barriers, newswire, electronically, ecdysis, painless,
# Nearest to marriage: rubens, prince, moldavia, her, instinctively, summoned, incompatible, yoshi,
# Nearest to units: smaller, hindley, aeg, specious, interchange, envisage, fw, universelle,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1792 0.0890 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1777 0.0881 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1757 0.0880 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1551 0.0884 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1563 0.0893 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1296 0.0889 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1519 0.0888 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1016 0.0893 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1968 0.0886 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2038 0.0884 sec/batch
# Nearest to only: visas, affecting, counselors, cotonou, theologies, flatt, complete, belgians,
# Nearest to there: portion, descending, chained, tshombe, clout, axonal, several, oppresses,
# Nearest to will: regimens, atheistic, get, achieve, diefenbaker, lughnasadh, do, penance,
# Nearest to his: he, octavian, pindar, stevie, colebrooke, dissonant, senatorial, auntie,
# Nearest to with: forage, defiance, amidst, fictitious, sinai, effect, hessians, tarim,
# Nearest to at: seminary, outlaw, ambrosius, roscoe, diploma, kiel, urgently, driscoll,
# Nearest to war: forces, armament, combat, commanded, independence, hansa, marshal, liberation,
# Nearest to used: bitches, determinant, coolers, cas, indispensable, addition, mood, vaccinated,
# Nearest to mean: niet, iranic, merseburg, krautrock, atheos, ipa, stubbornly, uncanonical,
# Nearest to writers: louisiane, clergy, novels, exiguus, tasker, lana, whitbread, pyotr,
# Nearest to operations: farc, linear, intruders, codepages, mandola, zhuhai, deeps, profitable,
# Nearest to orthodox: sacrament, sunni, mabuse, eastern, catholics, liturgy, creeds, presbyterian,
# Nearest to gold: silver, zinc, robber, craxi, amphibians, inoculated, blockading, cass,
# Nearest to cost: langdon, installation, buggy, ecdysis, painless, electronically, newswire, markets,
# Nearest to marriage: prince, rubens, moldavia, her, instinctively, summoned, marry, antipope,
# Nearest to units: smaller, specious, finances, fw, aeg, hindley, envisage, universelle,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2106 0.0898 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.0997 0.0887 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1338 0.0882 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1185 0.0884 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0171 0.0892 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1150 0.0896 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1270 0.0891 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0785 0.0897 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1703 0.0229 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0892 0.0895 sec/batch
# Nearest to only: affecting, visas, fitted, barking, flatt, cotonou, complete, incalculable,
# Nearest to there: portion, descending, chained, several, is, tshombe, clout, axonal,
# Nearest to will: regimens, atheistic, get, diefenbaker, lughnasadh, achieve, do, preparedness,
# Nearest to his: he, dissonant, octavian, pindar, stevie, pushing, colebrooke, auntie,
# Nearest to with: forage, amidst, defiance, effect, sinai, criticising, fictitious, masculist,
# Nearest to at: outlaw, maximum, kiel, seminary, roscoe, the, elliptic, diploma,
# Nearest to war: forces, armament, combat, commanded, hansa, postwar, liberation, independence,
# Nearest to used: bitches, determinant, addition, bitmap, coolers, indispensable, technicalities, cas,
# Nearest to mean: niet, iranic, krautrock, merseburg, nabla, stubbornly, atheos, uncanonical,
# Nearest to writers: louisiane, novels, clergy, tasker, whitbread, pyotr, lana, exiguus,
# Nearest to operations: farc, intruders, codepages, zhuhai, linear, deeps, carelessly, mandola,
# Nearest to orthodox: sunni, sacrament, mabuse, liturgy, creeds, eastern, christian, presbyterian,
# Nearest to gold: silver, zinc, robber, amphibians, inoculated, craxi, highwaymen, blockading,
# Nearest to cost: installation, langdon, electronically, painless, buggy, newswire, barriers, ecdysis,
# Nearest to marriage: rubens, instinctively, prince, moldavia, her, summoned, marry, incompatible,
# Nearest to units: smaller, specious, hindley, finances, unit, aeg, fw, envisage,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0530 0.0899 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0351 0.0880 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0508 0.0882 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0111 0.0884 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0212 0.0887 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0119 0.0888 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0590 0.0883 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0670 0.0889 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0946 0.0893 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9748 0.0894 sec/batch
# Nearest to only: affecting, visas, cotonou, fitted, complete, barking, incalculable, belgians,
# Nearest to there: portion, descending, is, chained, clout, several, axonal, conifer,
# Nearest to will: regimens, get, diefenbaker, lughnasadh, atheistic, do, achieve, foe,
# Nearest to his: he, octavian, wife, dissonant, colebrooke, pindar, stevie, auntie,
# Nearest to with: forage, defiance, effect, amidst, injecting, masculist, sinai, fictitious,
# Nearest to at: maximum, outlaw, relates, ambrosius, diploma, roscoe, kiel, elliptic,
# Nearest to war: forces, armament, combat, commanded, hansa, logistical, postwar, garrisons,
# Nearest to used: bitches, cas, determinant, vaccinated, addition, bitmap, technicalities, indispensable,
# Nearest to mean: niet, krautrock, iranic, merseburg, stubbornly, nabla, kimbundu, noonan,
# Nearest to writers: louisiane, novels, clergy, tasker, whitbread, pyotr, exiguus, unsound,
# Nearest to operations: farc, codepages, linear, zhuhai, intruders, deeps, carelessly, mandola,
# Nearest to orthodox: sacrament, sunni, mabuse, creeds, christian, liturgy, catholics, valentinians,
# Nearest to gold: silver, zinc, inoculated, amphibians, blockading, highwaymen, robber, craxi,
# Nearest to cost: langdon, electronically, painless, installation, buggy, ecdysis, newswire, appropriation,
# Nearest to marriage: rubens, instinctively, her, prince, moldavia, marry, summoned, incompatible,
# Nearest to units: smaller, unit, specious, regimental, hindley, aeg, fw, nonaligned,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9772 0.0911 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9964 0.0926 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9906 0.0900 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0073 0.0896 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0265 0.0896 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0213 0.0901 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0033 0.0892 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0915 0.0889 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 3.9847 0.0891 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0262 0.0895 sec/batch
# Nearest to only: affecting, complete, cotonou, visas, fitted, barking, formulae, incalculable,
# Nearest to there: is, portion, descending, clout, chained, preprocessing, oppresses, axonal,
# Nearest to will: regimens, get, diefenbaker, to, do, atheistic, lughnasadh, achieve,
# Nearest to his: he, pindar, stevie, dissonant, octavian, wife, colebrooke, auntie,
# Nearest to with: forage, effect, defiance, pharmacist, injecting, masculist, amidst, overlapped,
# Nearest to at: outlaw, diploma, ambrosius, relates, seminary, elliptic, maximum, warmest,
# Nearest to war: forces, armament, combat, hansa, logistical, commanded, garrisons, postwar,
# Nearest to used: bitches, cas, vaccinated, technicalities, bitmap, addition, determinant, coca,
# Nearest to mean: niet, iranic, merseburg, uncanonical, noonan, native, krautrock, stubbornly,
# Nearest to writers: louisiane, novels, tasker, whitbread, pyotr, clergy, lana, exiguus,
# Nearest to operations: farc, linear, zhuhai, carelessly, codepages, deeps, mandola, intruders,
# Nearest to orthodox: sunni, sacrament, eastern, catholics, mabuse, christian, creeds, liturgy,
# Nearest to gold: silver, zinc, highwaymen, robber, werther, amphibians, craxi, blockading,
# Nearest to cost: electronically, langdon, painless, appropriation, buggy, installation, tenderness, ecdysis,
# Nearest to marriage: rubens, her, instinctively, prince, marry, moldavia, summoned, ailuropoda,
# Nearest to units: smaller, unit, hindley, specious, regimental, aeg, fw, tesla,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0097 0.0901 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0293 0.0893 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0487 0.0890 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.9660 0.0889 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0309 0.0887 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0060 0.0886 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0241 0.0883 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0183 0.0884 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0549 0.0883 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 3.9998 0.0886 sec/batch
# Nearest to only: cotonou, affecting, visas, fitted, counselors, barking, seconds, obligated,
# Nearest to there: portion, descending, clout, is, oppresses, preprocessing, chained, tshombe,
# Nearest to will: regimens, get, diefenbaker, to, do, lughnasadh, penance, achieve,
# Nearest to his: he, octavian, wife, colebrooke, tey, pindar, rhetorician, dissonant,
# Nearest to with: forage, defiance, amidst, sinai, effect, masculist, urantia, contentions,
# Nearest to at: diploma, seminary, outlaw, ambrosius, roscoe, relates, warmest, pergamon,
# Nearest to war: forces, armament, logistical, commanded, combat, hansa, postwar, independence,
# Nearest to used: bitches, cas, technicalities, addition, vaccinated, bitmap, widely, determinant,
# Nearest to mean: niet, iranic, merseburg, uncanonical, kimbundu, native, marshlands, koontz,
# Nearest to writers: louisiane, novels, tasker, whitbread, pyotr, unsound, clergy, lana,
# Nearest to operations: farc, linear, zhuhai, intruders, carelessly, deeps, mandola, arming,
# Nearest to orthodox: sacrament, sunni, eastern, stylebook, catholics, liturgy, englishmen, creeds,
# Nearest to gold: silver, zinc, amphibians, highwaymen, robber, inoculated, blockading, werther,
# Nearest to cost: electronically, langdon, painless, buggy, evo, newswire, tenderness, installation,
# Nearest to marriage: rubens, her, marry, instinctively, prince, moldavia, creatively, wives,
# Nearest to units: smaller, unit, regimental, fw, hindley, specious, aeg, tesla,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0235 0.0907 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9579 0.0893 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9996 0.0894 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0105 0.0891 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0328 0.0887 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1019 0.0883 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0843 0.0886 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0214 0.0885 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9779 0.0884 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0115 0.0880 sec/batch
# Nearest to only: cotonou, affecting, deborah, fitted, incalculable, visas, barking, complete,
# Nearest to there: portion, descending, chained, preprocessing, is, clout, axonal, oppresses,
# Nearest to will: to, regimens, do, get, diefenbaker, lughnasadh, atheistic, merozoites,
# Nearest to his: he, octavian, tey, stevie, dissonant, pindar, graduated, colebrooke,
# Nearest to with: forage, defiance, sinai, hessians, amidst, effect, masculist, glaser,
# Nearest to at: diploma, seminary, outlaw, warmest, interchange, kiel, ambrosius, roscoe,
# Nearest to war: forces, armament, logistical, hansa, independence, liberation, combat, garrisons,
# Nearest to used: technicalities, cas, bitches, addition, bitmap, determinant, indispensable, badges,
# Nearest to mean: niet, iranic, merseburg, marshlands, uncanonical, koontz, kimbundu, noonan,
# Nearest to writers: louisiane, novels, tasker, whitbread, births, pyotr, clergy, unsound,
# Nearest to operations: linear, farc, codepages, zhuhai, arming, mandola, carelessly, intruders,
# Nearest to orthodox: sacrament, sunni, stylebook, eastern, mabuse, creeds, englishmen, autocephalous,
# Nearest to gold: silver, zinc, medal, highwaymen, amphibians, robber, werther, inoculated,
# Nearest to cost: electronically, langdon, painless, buggy, appropriation, evo, tenderness, finance,
# Nearest to marriage: her, rubens, marry, prince, instinctively, moldavia, creatively, wives,
# Nearest to units: unit, smaller, regimental, specious, fw, tesla, afvs, hindley,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9117 0.0893 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9620 0.0890 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0078 0.0890 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9838 0.0880 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0114 0.0878 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.9835 0.0889 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9571 0.0881 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9167 0.0875 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9388 0.0869 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9065 0.0874 sec/batch
# Nearest to only: cotonou, deborah, fitted, incalculable, complete, barking, affecting, headset,
# Nearest to there: portion, preprocessing, descending, is, clout, chained, persons, axonal,
# Nearest to will: regimens, to, do, get, atheistic, diefenbaker, obligation, lughnasadh,
# Nearest to his: he, octavian, tey, recht, stevie, graduated, rhetorician, elaborated,
# Nearest to with: forage, defiance, sinai, amidst, effect, masculist, injecting, hessians,
# Nearest to at: diploma, seminary, ambrosius, outlaw, warmest, relates, maximum, kiel,
# Nearest to war: forces, armament, logistical, combat, hansa, liberation, marshal, napoleon,
# Nearest to used: cas, addition, technicalities, bitches, coca, determinant, bitmap, vaccinated,
# Nearest to mean: niet, marshlands, merseburg, iranic, uncanonical, koontz, laplacian, kimbundu,
# Nearest to writers: louisiane, novels, tasker, births, clergy, whitbread, pyotr, unsound,
# Nearest to operations: linear, farc, arming, zhuhai, codepages, carelessly, deeps, intruders,
# Nearest to orthodox: sacrament, sunni, stylebook, mabuse, christian, catholics, ladislaus, eastern,
# Nearest to gold: silver, zinc, medal, highwaymen, werther, blockading, robber, inoculated,
# Nearest to cost: electronically, painless, buggy, appropriation, langdon, bile, tenderness, evo,
# Nearest to marriage: her, marry, rubens, instinctively, prince, moldavia, wives, creatively,
# Nearest to units: unit, smaller, regimental, specious, tesla, fw, afvs, hindley,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9345 0.0888 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.8841 0.0881 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9526 0.0879 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9626 0.0879 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9610 0.0892 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9350 0.0905 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8561 0.0922 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9247 0.0905 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8492 0.0905 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9212 0.0900 sec/batch
# Nearest to only: deborah, cotonou, incalculable, affecting, fitted, complete, barking, headset,
# Nearest to there: is, preprocessing, portion, descending, clout, chained, axonal, oppresses,
# Nearest to will: regimens, do, to, get, atheistic, diefenbaker, stationary, merozoites,
# Nearest to his: he, octavian, tey, dissonant, senatorial, stevie, inviolable, recht,
# Nearest to with: forage, effect, injecting, galvanometer, pharmacist, amidst, sinai, chopsticks,
# Nearest to at: diploma, seminary, ambrosius, roscoe, relates, outlaw, maximum, warmest,
# Nearest to war: forces, armament, logistical, combat, hansa, liberation, garrisons, independence,
# Nearest to used: cas, vaccinated, addition, bitches, widely, technicalities, determinant, bitmap,
# Nearest to mean: niet, merseburg, marshlands, koontz, iranic, uncanonical, kimbundu, laplacian,
# Nearest to writers: louisiane, novels, tasker, births, clergy, whitbread, unsound, pyotr,
# Nearest to operations: farc, linear, zhuhai, arming, codepages, operation, intruders, carelessly,
# Nearest to orthodox: sacrament, stylebook, sunni, catholics, mabuse, valentinians, christian, eastern,
# Nearest to gold: silver, zinc, medal, highwaymen, werther, inoculated, robber, amphibians,
# Nearest to cost: painless, electronically, appropriation, langdon, bile, evo, tenderness, buggy,
# Nearest to marriage: her, instinctively, marry, rubens, wives, moldavia, prince, creatively,
# Nearest to units: unit, smaller, regimental, residing, tesla, hindley, fw, mi,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9250 0.0913 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9037 0.0899 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9249 0.0896 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9534 0.0890 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9953 0.0891 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.8815 0.0891 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9386 0.0893 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9155 0.0892 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9331 0.0890 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9111 0.0883 sec/batch
# Nearest to only: deborah, affecting, cotonou, complete, incalculable, barking, fitted, renditions,
# Nearest to there: is, portion, clout, preprocessing, descending, chained, several, axonal,
# Nearest to will: to, do, get, regimens, diefenbaker, lughnasadh, merozoites, obligation,
# Nearest to his: he, stevie, octavian, dissonant, graduated, recht, tey, pindar,
# Nearest to with: forage, effect, substantive, masculist, galvanometer, amidst, bcs, urantia,
# Nearest to at: diploma, seminary, outlaw, relates, ambrosius, roscoe, elliptic, maximum,
# Nearest to war: forces, armament, combat, logistical, hansa, liberation, napoleon, postwar,
# Nearest to used: cas, vaccinated, addition, widely, bitches, technicalities, coca, bitmap,
# Nearest to mean: merseburg, niet, iranic, uncanonical, koontz, shroud, noonan, stubbornly,
# Nearest to writers: louisiane, tasker, novels, births, whitbread, unsound, clergy, contemporaneously,
# Nearest to operations: farc, arming, zhuhai, linear, codepages, carelessly, intruders, glace,
# Nearest to orthodox: sacrament, stylebook, sunni, eastern, catholics, autocephalous, mabuse, englishmen,
# Nearest to gold: silver, medal, zinc, highwaymen, werther, robber, inoculated, craxi,
# Nearest to cost: electronically, appropriation, langdon, tenderness, painless, bile, buggy, evo,
# Nearest to marriage: her, instinctively, marry, rubens, prince, moldavia, creatively, wives,
# Nearest to units: unit, regimental, smaller, tesla, kilogram, fw, afvs, hindley,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9383 0.0893 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9284 0.0887 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9186 0.0885 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9476 0.0884 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9743 0.0882 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9369 0.0883 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9293 0.0892 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9112 0.0898 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9000 0.0892 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9457 0.0909 sec/batch
# Nearest to only: cotonou, deborah, incalculable, complete, affecting, barking, visas, headset,
# Nearest to there: is, preprocessing, portion, clout, certain, persons, descending, chained,
# Nearest to will: to, do, regimens, get, diefenbaker, obligation, lughnasadh, must,
# Nearest to his: he, graduated, octavian, stevie, dissonant, recht, rhetorician, tey,
# Nearest to with: forage, sinai, substantive, galvanometer, amidst, urantia, depeche, manos,
# Nearest to at: diploma, seminary, warmest, outlaw, relates, ambrosius, interchange, tropics,
# Nearest to war: forces, armament, combat, hansa, logistical, lawrence, postwar, waged,
# Nearest to used: cas, addition, technicalities, widely, vaccinated, bitmap, term, bitches,
# Nearest to mean: merseburg, niet, uncanonical, marshlands, iranic, koontz, laplacian, stubbornly,
# Nearest to writers: louisiane, tasker, novels, births, whitbread, autodidacts, unsound, contemporaneously,
# Nearest to operations: farc, linear, arming, zhuhai, codepages, glace, intruders, deeps,
# Nearest to orthodox: sacrament, stylebook, sunni, eastern, mabuse, catholics, englishmen, autocephalous,
# Nearest to gold: silver, medal, zinc, highwaymen, robber, werther, amphibians, inoculated,
# Nearest to cost: electronically, appropriation, langdon, money, tenderness, painless, evo, bile,
# Nearest to marriage: her, marry, rubens, prince, instinctively, wives, moldavia, creatively,
# ...
# Nearest to writers: births, louisiane, novelists, autodidacts, literature, strabo, scythian, playwrights,
# Nearest to operations: arming, tannenberg, algebra, dzerzhinsky, demobilization, rectified, intruders, sparse,
# Nearest to orthodox: stylebook, sunni, sacrament, eastern, catholics, aphorism, mabuse, creeds,
# Nearest to gold: silver, medal, medals, bronze, statically, highwaymen, earrings, nickel,
# Nearest to cost: electronically, evo, tenderness, painless, deductions, savings, money, appropriation,
# Nearest to marriage: her, marry, siblings, instinctively, wives, sex, incompatible, remarried,
# Nearest to units: unit, regimental, residing, kilogram, perceive, cgs, mi, housing,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7115 0.0903 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.7517 0.0901 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.7343 0.0892 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.7814 0.0889 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.7388 0.0885 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.7943 0.0890 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.7498 0.0890 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7334 0.0881 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.7714 0.0884 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.7758 0.0881 sec/batch
# Nearest to only: it, two, complete, zero, cotonou, circumscription, finales, renditions,
# Nearest to there: certain, several, medically, is, housing, are, persons, attesting,
# Nearest to will: merozoites, do, diefenbaker, lughnasadh, to, ramp, councillors, must,
# Nearest to his: he, dissonant, graduated, adulthood, mcclory, career, respected, encamped,
# Nearest to with: forage, in, hexen, one, syngman, a, pharmacist, preinstalled,
# Nearest to at: diploma, gymnasium, while, seminary, warmest, ives, the, carleton,
# Nearest to war: forces, liberation, fighting, reclassified, karelia, civil, combat, armament,
# Nearest to used: using, widely, term, overseen, optics, lubrication, pt, numerals,
# Nearest to mean: merseburg, lots, inequality, koontz, average, stubbornly, uncanonical, hotter,
# Nearest to writers: births, autodidacts, novelists, literature, louisiane, tasker, playwrights, altering,
# Nearest to operations: arming, tannenberg, dzerzhinsky, algebra, sparse, demobilization, farc, intruders,
# Nearest to orthodox: stylebook, sacrament, sunni, eastern, catholics, creeds, serbian, aphorism,
# Nearest to gold: silver, medal, medals, bronze, statically, highwaymen, earrings, nickel,
# Nearest to cost: electronically, evo, tenderness, painless, deductions, money, bile, savings,
# Nearest to marriage: her, marry, siblings, instinctively, wives, remarried, prince, imperialistic,
# Nearest to units: unit, regimental, kilogram, perceive, residing, housing, cgs, mi,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.7794 0.0894 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.7632 0.0893 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.7535 0.0894 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7244 0.0891 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.7908 0.0896 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.6962 0.0889 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.8566 0.0887 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8077 0.0892 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8003 0.0890 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7181 0.0888 sec/batch
# Nearest to only: it, complete, two, finales, zero, circumscription, cotonou, renditions,
# Nearest to there: certain, are, medically, is, several, housing, other, attesting,
# Nearest to will: merozoites, do, lughnasadh, diefenbaker, councillors, must, to, teams,
# Nearest to his: he, graduated, dissonant, career, adulthood, work, went, tommie,
# Nearest to with: in, one, forage, a, syngman, the, hexen, also,
# Nearest to at: diploma, gymnasium, seminary, while, carleton, restore, warmest, fayetteville,
# Nearest to war: forces, liberation, reclassified, armament, karelia, fighting, combat, troops,
# Nearest to used: using, widely, term, often, numerals, overseen, lubrication, badges,
# Nearest to mean: merseburg, lots, koontz, average, inequality, iranic, darboux, marshlands,
# Nearest to writers: births, novelists, autodidacts, scifan, louisiane, tasker, chicagoans, literature,
# Nearest to operations: arming, tannenberg, dzerzhinsky, algebra, sparse, boolean, rectified, demobilization,
# Nearest to orthodox: stylebook, sacrament, sunni, serbian, catholics, aphorism, creeds, eastern,
# Nearest to gold: silver, medal, medals, bronze, statically, coins, nickel, earrings,
# Nearest to cost: evo, tenderness, electronically, painless, deductions, money, savings, bile,
# Nearest to marriage: her, marry, siblings, instinctively, wives, homosexuals, sex, remarried,
# Nearest to units: unit, kilogram, regimental, residing, perceive, cgs, housing, mi,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7075 0.0899 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.7359 0.0891 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.6805 0.0892 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.7749 0.0888 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7570 0.0888 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.7670 0.0888 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.7349 0.0668 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7172 0.0885 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7405 0.0880 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.7599 0.0876 sec/batch
# Nearest to only: complete, two, finales, zero, renditions, circumscription, it, chance,
# Nearest to there: certain, is, are, medically, housing, several, other, rare,
# Nearest to will: merozoites, do, lughnasadh, diefenbaker, must, councillors, durga, teams,
# Nearest to his: he, dissonant, was, graduated, adulthood, career, kronos, encamped,
# Nearest to with: in, forage, a, syngman, hexen, acidity, thicknesses, the,
# Nearest to at: diploma, gymnasium, while, the, seminary, ambrosius, restore, shia,
# Nearest to war: forces, civil, liberation, armament, reclassified, karelia, fighting, troops,
# Nearest to used: using, widely, lubrication, pt, often, codings, ickey, optics,
# Nearest to mean: merseburg, average, inequality, lots, koontz, marshlands, darboux, phrasing,
# Nearest to writers: births, novelists, autodidacts, humanists, scifan, espousing, literature, tasker,
# Nearest to operations: arming, tannenberg, algebra, dzerzhinsky, sparse, rectified, boolean, aden,
# Nearest to orthodox: stylebook, sacrament, serbian, sunni, marketer, mabuse, catholics, lefebvre,
# Nearest to gold: silver, medal, medals, statically, bronze, coins, earrings, nickel,
# Nearest to cost: evo, tenderness, painless, electronically, deductions, savings, money, appropriation,
# Nearest to marriage: her, marry, siblings, instinctively, wives, sex, homosexuals, remarried,
# Nearest to units: unit, kilogram, regimental, cgs, perceive, residing, housing, metrication,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.6754 0.0890 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7289 0.0888 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.6652 0.0885 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7518 0.0881 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.7573 0.0883 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.7320 0.0890 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.7603 0.0892 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.6325 0.0892 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7053 0.0899 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.6523 0.0892 sec/batch
# Nearest to only: complete, it, two, zero, finales, renditions, circumscription, a,
# Nearest to there: certain, is, are, several, other, housing, medically, all,
# Nearest to will: merozoites, do, lughnasadh, diefenbaker, must, to, foe, councillors,
# Nearest to his: he, dissonant, adulthood, career, graduated, kronos, encamped, unprovoked,
# Nearest to with: in, one, a, forage, syngman, hexen, also, acidity,
# Nearest to at: diploma, while, the, qantas, gymnasium, warmest, ives, relates,
# Nearest to war: forces, reclassified, fighting, liberation, karelia, hostilities, combat, armament,
# Nearest to used: using, widely, often, lubrication, are, optics, some, use,
# Nearest to mean: merseburg, average, inequality, koontz, marshlands, stubbornly, reached, darboux,
# Nearest to writers: births, novelists, autodidacts, humanists, humanitarians, louisiane, scifan, literature,
# Nearest to operations: arming, tannenberg, algebra, dzerzhinsky, boolean, demobilization, sparse, aden,
# Nearest to orthodox: stylebook, sacrament, serbian, catholics, sunni, creeds, aphorism, eastern,
# Nearest to gold: silver, medal, medals, bronze, statically, nickel, earrings, coins,
# Nearest to cost: evo, tenderness, painless, savings, appropriation, electronically, money, deductions,
# Nearest to marriage: her, marry, instinctively, siblings, wives, sex, homosexuals, wandrei,
# Nearest to units: unit, regimental, kilogram, housing, residing, perceive, cgs, smaller,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.6999 0.0899 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7078 0.0888 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.7588 0.0890 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.6960 0.0891 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7220 0.0883 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.7931 0.0884 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7345 0.0886 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7372 0.0883 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7210 0.0883 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.7349 0.0883 sec/batch
# Nearest to only: it, complete, a, renditions, finales, arrangements, circumscription, and,
# Nearest to there: certain, is, are, several, all, housing, other, medically,
# Nearest to will: merozoites, do, to, lughnasadh, must, diefenbaker, teams, xserve,
# Nearest to his: he, dissonant, adulthood, career, graduated, went, kronos, was,
# Nearest to with: in, a, also, one, forage, hexen, syngman, preinstalled,
# Nearest to at: diploma, ives, the, warmest, gymnasium, while, relates, rectangular,
# Nearest to war: forces, reclassified, liberation, karelia, fighting, combat, hostilities, tigers,
# Nearest to used: using, widely, optics, ickey, term, codings, overseen, thesaurus,
# Nearest to mean: merseburg, stubbornly, average, inequality, koontz, zachary, marshlands, lots,
# Nearest to writers: births, novelists, autodidacts, humanists, literature, scifan, tasker, playwrights,
# Nearest to operations: arming, dzerzhinsky, algebra, tannenberg, sparse, demobilization, boolean, aden,
# Nearest to orthodox: stylebook, eastern, catholics, sacrament, sunni, autocephalous, creeds, serbian,
# Nearest to gold: silver, medal, medals, statically, bronze, highwaymen, coins, earrings,
# Nearest to cost: evo, tenderness, money, painless, savings, electronically, appropriation, deductions,
# Nearest to marriage: her, marry, siblings, instinctively, wives, sex, herself, remarried,
# Nearest to units: unit, kilogram, regimental, housing, residing, cgs, perceive, metrication,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.7102 0.0891 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7596 0.0884 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7343 0.0885 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7082 0.0884 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.7758 0.0886 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.7492 0.0891 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.7279 0.0891 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.7152 0.0900 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7344 0.0899 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7217 0.0899 sec/batch
# Nearest to only: it, two, complete, a, zero, circumscription, and, nature,
# Nearest to there: certain, are, is, several, medically, housing, other, rare,
# Nearest to will: merozoites, to, do, lughnasadh, must, diefenbaker, foe, they,
# Nearest to his: he, dissonant, kronos, continued, adulthood, career, encamped, respected,
# Nearest to with: in, one, a, also, the, forage, and, both,
# Nearest to at: diploma, ives, restore, while, gymnasium, warmest, rectangular, the,
# Nearest to war: forces, liberation, hostilities, karelia, reclassified, fighting, germany, troops,
# Nearest to used: using, widely, also, usually, optics, term, often, use,
# Nearest to mean: merseburg, average, inequality, lots, marshlands, stubbornly, zachary, koontz,
# Nearest to writers: births, autodidacts, novelists, literature, scifan, humanists, playwrights, strabo,
# Nearest to operations: arming, dzerzhinsky, tannenberg, sparse, algebra, aden, demobilization, intruders,
# Nearest to orthodox: stylebook, eastern, sacrament, serbian, catholics, creeds, autocephalous, sunni,
# Nearest to gold: silver, medal, medals, statically, bronze, nickel, coins, highwaymen,
# Nearest to cost: evo, tenderness, money, savings, electronically, painless, appropriation, countess,
# Nearest to marriage: her, marry, siblings, instinctively, wives, sex, remarried, divorces,
# Nearest to units: unit, regimental, kilogram, housing, perceive, cgs, residing, metrication,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.7845 0.0910 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.6790 0.0893 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8406 0.0888 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.7949 0.0889 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8082 0.0896 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.6926 0.0914 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.6607 0.0888 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.7399 0.0890 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.6389 0.0894 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.7384 0.0895 sec/batch
# Nearest to only: it, complete, two, finales, a, circumscription, chance, renditions,
# Nearest to there: certain, are, is, medically, rare, other, several, housing,
# Nearest to will: do, merozoites, lughnasadh, diefenbaker, must, to, thousand, councillors,
# Nearest to his: he, dissonant, graduated, encamped, adulthood, respected, was, work,
# Nearest to with: in, also, the, a, forage, one, both, syngman,
# Nearest to at: warmest, diploma, the, while, restore, gymnasium, ives, exchanging,
# Nearest to war: forces, hostilities, liberation, reclassified, karelia, germany, troops, fighting,
# Nearest to used: using, optics, widely, also, usually, term, ickey, often,
# Nearest to mean: merseburg, average, inequality, phrasing, darboux, lots, zachary, marshlands,
# Nearest to writers: births, novelists, autodidacts, scifan, humanists, literature, chicagoans, humanitarians,
# Nearest to operations: arming, dzerzhinsky, tannenberg, sparse, algebra, aden, peacekeeping, boolean,
# Nearest to orthodox: stylebook, serbian, eastern, creeds, sacrament, sunni, autocephalous, catholics,
# Nearest to gold: silver, medal, medals, statically, bronze, coins, highwaymen, earrings,
# Nearest to cost: evo, tenderness, money, savings, appropriation, electronically, countess, deductions,
# Nearest to marriage: her, marry, siblings, instinctively, sex, wives, divorce, homosexuals,
# Nearest to units: unit, kilogram, housing, regimental, perceive, cgs, residing, cgpm,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.7287 0.0899 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7262 0.0884 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
